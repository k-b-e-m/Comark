# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,3])

# Java

predbst = np.array([348,1224,17853])

compbst = np.array([376,1068,11169])

slfactor2bst = np.array([279,713,6953])

slfactor3bst = np.array([283,692,6097])

slfactor4bst = np.array([332,809,6216])

slfactor5bst = np.array([432,1095,7705])

# C-X86
xpredbst = np.array([212.66,553.66,2909.66])

xcompbst = np.array([456.3,859.33,1052])

xslfactor2bst = np.array([468,826.33,1021.33])

xslfactor3bst = np.array([409.33,663,716.66])

xslfactor4bst = np.array([405.33,642.33,681])

xslfactor5bst = np.array([465.3,693.33,750])

#C -AARCH64
xxpredbst = np.array([150.5,592.71,9000.04])

xxcompbst = np.array([289.73,933.13,8746.9])

xxslfactor2bst = np.array([287.47,924.78,8687.12])

xxslfactor3bst = np.array([238.58,602.47,4609.03])

xxslfactor4bst = np.array([252.1,623.51,5147.88])

xxslfactor5bst = np.array([314.88,769.76,5312])

fig, ax = plt.subplots()

#ax.plot(x,predbst, "o-", label = "predbst Java")
#ax.plot(x,compbst, "o-", label = "compbst Java")
#ax.plot(x,slfactor2bst, "o-", label = "sl2bst Java")
#ax.plot(x,slfactor3bst, "o-", label = "sl3bst Java")
#ax.plot(x,slfactor4bst, "o-", label = "sl4bst Java")
#ax.plot(x,slfactor5bst, "o-", label = "sl5bst Java")


#ax.plot(x,xxpredbst, "o-", label = "predbst C-aarch")
#ax.plot(x,xcompbst, "o-", label = "compbst C-aarch")
#ax.plot(x,xxslfactor2bst, "o-", label = "sl2bst C-aarch")
#ax.plot(x,xxslfactor3bst, "o-", label = "sl3bst C-aarch")
#ax.plot(x,xxslfactor4bst, ".-", label = "sl4bst C-aarch")
#ax.plot(x,xxslfactor5bst, "o-", label = "sl5bst C-aarch")

#ax.plot(x,xpredbst, "o-", label = "predbst C-X86")
#ax.plot(x,xcompbst, "o-", label = "compbst C-X86")
ax.plot(x,xslfactor2bst, "o-", label = "sl2bst C-X86")
ax.plot(x,xslfactor3bst, "o-", label = "sl3bst C-X86")
ax.plot(x,xslfactor4bst, "o-", label = "sl4bst C-X86")
ax.plot(x,xslfactor5bst, "o-", label = "sl5bst C-X86")

ax.legend(bbox_to_anchor=(1, 1))
plt.xticks([1,2,3])
ax.set_xticklabels( ('2^9', '2^19','2^29') )
# Out:
# [Text(1, 0, '2^9'), Text(2, 0, '2^19'), Text(3, 0, '2^29')]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,3])

# Java

predbst = np.array([348,1224,17853])

compbst = np.array([376,1068,11169])

slfactor2bst = np.array([279,713,6953])

slfactor3bst = np.array([283,692,6097])

slfactor4bst = np.array([332,809,6216])

slfactor5bst = np.array([432,1095,7705])

# C-X86
xpredbst = np.array([212.66,553.66,2909.66])

xcompbst = np.array([456.3,859.33,1052])

xslfactor2bst = np.array([468,826.33,1021.33])

xslfactor3bst = np.array([409.33,663,716.66])

xslfactor4bst = np.array([405.33,642.33,681])

xslfactor5bst = np.array([465.3,693.33,750])

#C -AARCH64
xxpredbst = np.array([150.5,592.71,9000.04])

xxcompbst = np.array([289.73,933.13,8746.9])

xxslfactor2bst = np.array([287.47,924.78,8687.12])

xxslfactor3bst = np.array([238.58,602.47,4609.03])

xxslfactor4bst = np.array([252.1,623.51,5147.88])

xxslfactor5bst = np.array([314.88,769.76,5312])

fig, ax = plt.subplots()

ax.plot(x,xpredbst, "o-", label = "predbst C-aarch")
ax.plot(x,xcompbst, "o-", label = "compbst C-aarch")
ax.plot(x,xslfactor2bst, "o-", label = "sl2bst C-aarch")
ax.plot(x,xslfactor3bst, "o-", label = "sl3bst C-aarch")
ax.plot(x,xslfactor4bst, "o-", label = "sl4bst C-aarch")
ax.plot(x,xslfactor5bst, "o-", label = "sl5bst C-aarch")

ax.plot(x,predbst, "o--", label = "predbst Java")
ax.plot(x,compbst, "o--", label = "compbst Java")
ax.plot(x,slfactor2bst, "o--", label = "sl2bst Java")
ax.plot(x,slfactor3bst, "o--", label = "sl3bst Java")
ax.plot(x,slfactor4bst, "o--", label = "sl4bst Java")
ax.plot(x,slfactor5bst, "o--", label = "sl5bst Java")

ax.plot(x,xpredbst, "o:", label = "predbst C-X86")
ax.plot(x,xcompbst, "o:", label = "compbst C-X86")
ax.plot(x,xslfactor2bst, "o:", label = "sl2bst C-X86")
ax.plot(x,xslfactor3bst, "o:", label = "sl3bst C-X86")
ax.plot(x,xslfactor4bst, "o:", label = "sl4bst C-X86")
ax.plot(x,xslfactor5bst, "o:", label = "sl5bst C-X86")

ax.legend(bbox_to_anchor=(1, 1))
plt.xticks([1,2,3])
ax.set_xticklabels( ('2^9', '2^19','2^29') )
# Out:
# [Text(1, 0, '2^9'), Text(2, 0, '2^19'), Text(3, 0, '2^29')]

# %%
####
# From 2^9 to 2^19
####
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,3])

# Java

predbst = np.array([348,1224,17853])

compbst = np.array([376,1068,11169])

slfactor2bst = np.array([279,713,6953])

slfactor3bst = np.array([283,692,6097])

slfactor4bst = np.array([332,809,6216])

slfactor5bst = np.array([432,1095,7705])

# C-X86
xpredbst = np.array([212.66,553.66,2909.66])

xcompbst = np.array([456.3,859.33,1052])

xslfactor2bst = np.array([468,826.33,1021.33])

xslfactor3bst = np.array([409.33,663,716.66])

xslfactor4bst = np.array([405.33,642.33,681])

xslfactor5bst = np.array([465.3,693.33,750])

#C -AARCH64
xxpredbst = np.array([150.5,592.71,9000.04])

xxcompbst = np.array([289.73,933.13,8746.9])

xxslfactor2bst = np.array([287.47,924.78,8687.12])

xxslfactor3bst = np.array([238.58,602.47,4609.03])

xxslfactor4bst = np.array([252.1,623.51,5147.88])

xxslfactor5bst = np.array([314.88,769.76,5312])

fig, ax = plt.subplots()

ax.plot(x,xpredbst, "o-", label = "predbst C-aarch")
ax.plot(x,xcompbst, "o-", label = "compbst C-aarch")
ax.plot(x,xslfactor2bst, "o-", label = "sl2bst C-aarch")
ax.plot(x,xslfactor3bst, "o-", label = "sl3bst C-aarch")
ax.plot(x,xslfactor4bst, "o-", label = "sl4bst C-aarch")
ax.plot(x,xslfactor5bst, "o-", label = "sl5bst C-aarch")

ax.plot(x,predbst, "o--", label = "predbst Java")
ax.plot(x,compbst, "o--", label = "compbst Java")
ax.plot(x,slfactor2bst, "o--", label = "sl2bst Java")
ax.plot(x,slfactor3bst, "o--", label = "sl3bst Java")
ax.plot(x,slfactor4bst, "o--", label = "sl4bst Java")
ax.plot(x,slfactor5bst, "o--", label = "sl5bst Java")

ax.plot(x,xpredbst, "o:", label = "predbst C-X86")
ax.plot(x,xcompbst, "o:", label = "compbst C-X86")
ax.plot(x,xslfactor2bst, "o:", label = "sl2bst C-X86")
ax.plot(x,xslfactor3bst, "o:", label = "sl3bst C-X86")
ax.plot(x,xslfactor4bst, "o:", label = "sl4bst C-X86")
ax.plot(x,xslfactor5bst, "o:", label = "sl5bst C-X86")

ax.legend(bbox_to_anchor=(1, 1))
plt.xticks([1,2,3])
ax.set_xticklabels( ('2^9', '2^19','2^29') )
ax.set_xlim(1,2)
ax.set_ylim(0,1300)
# Out:
# (0.0, 1300.0)

# %%
####
# From 2^19 to 2^29
####
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,3])

# Java

predbst = np.array([348,1224,17853])

compbst = np.array([376,1068,11169])

slfactor2bst = np.array([279,713,6953])

slfactor3bst = np.array([283,692,6097])

slfactor4bst = np.array([332,809,6216])

slfactor5bst = np.array([432,1095,7705])

# C-X86
xpredbst = np.array([212.66,553.66,2909.66])

xcompbst = np.array([456.3,859.33,1052])

xslfactor2bst = np.array([468,826.33,1021.33])

xslfactor3bst = np.array([409.33,663,716.66])

xslfactor4bst = np.array([405.33,642.33,681])

xslfactor5bst = np.array([465.3,693.33,750])

#C -AARCH64
xxpredbst = np.array([150.5,592.71,9000.04])

xxcompbst = np.array([289.73,933.13,8746.9])

xxslfactor2bst = np.array([287.47,924.78,8687.12])

xxslfactor3bst = np.array([238.58,602.47,4609.03])

xxslfactor4bst = np.array([252.1,623.51,5147.88])

xxslfactor5bst = np.array([314.88,769.76,5312])

fig, ax = plt.subplots()

ax.plot(x,xpredbst, "o-", label = "predbst C-aarch")
ax.plot(x,xcompbst, "o-", label = "compbst C-aarch")
ax.plot(x,xslfactor2bst, "o-", label = "sl2bst C-aarch")
ax.plot(x,xslfactor3bst, "o-", label = "sl3bst C-aarch")
ax.plot(x,xslfactor4bst, "o-", label = "sl4bst C-aarch")
ax.plot(x,xslfactor5bst, "o-", label = "sl5bst C-aarch")

ax.plot(x,predbst, "o--", label = "predbst Java")
ax.plot(x,compbst, "o--", label = "compbst Java")
ax.plot(x,slfactor2bst, "o--", label = "sl2bst Java")
ax.plot(x,slfactor3bst, "o--", label = "sl3bst Java")
ax.plot(x,slfactor4bst, "o--", label = "sl4bst Java")
ax.plot(x,slfactor5bst, "o--", label = "sl5bst Java")

ax.plot(x,xpredbst, "o:", label = "predbst C-X86")
ax.plot(x,xcompbst, "o:", label = "compbst C-X86")
ax.plot(x,xslfactor2bst, "o:", label = "sl2bst C-X86")
ax.plot(x,xslfactor3bst, "o:", label = "sl3bst C-X86")
ax.plot(x,xslfactor4bst, "o:", label = "sl4bst C-X86")
ax.plot(x,xslfactor5bst, "o:", label = "sl5bst C-X86")

ax.legend(bbox_to_anchor=(1, 1))
plt.xticks([1,2,3])
ax.set_xticklabels( ('2^9', '2^19','2^29') )
ax.set_xlim(2,3.1)
ax.set_ylim(600,19000)
# Out:
# (600.0, 19000.0)
